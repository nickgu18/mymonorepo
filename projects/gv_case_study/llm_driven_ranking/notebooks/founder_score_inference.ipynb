# %% [markdown]
# # Founder Score Inference Notebook
#
# Use this notebook to run the ./launch.sh demo pipeline in inference mode against the real founder dataset.

# %%
import os
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
DATA_DIR = PROJECT_ROOT / 'data' / 'real'
print(f'Project root: {PROJECT_ROOT}')
print(f'Inference data dir: {DATA_DIR}')

# %% [markdown]
# ## 1. Load serialized founders
# This mirrors the CLI pipeline so notebooks stay reproducible.

# %%
from llm_driven_ranking.src.mlflow_llm_quickstart import main as run_demo

run_demo()
